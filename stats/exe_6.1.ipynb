# %%
print("hi")
# Out:
# hi

# %%
import pandas as pd

# %%
baby_names = pd.read_csv('https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/06_Stats/US_Baby_Names/US_Baby_Names_right.csv')
baby_names.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1016395 entries, 0 to 1016394
# Data columns (total 7 columns):
#  #   Column      Non-Null Count    Dtype
# ---  ------      --------------    -----
#  0   Unnamed: 0  1016395 non-null  int64
#  1   Id          1016395 non-null  int64
#  2   Name        1016395 non-null  str
#  3   Year        1016395 non-null  int64
#  4   Gender      1016395 non-null  str
#  5   State       1016395 non-null  str
#  6   Count       1016395 non-null  int64
# dtypes: int64(4), str(3)
# memory usage: 54.3 MB

# %%
# Delete the column 'Unnamed: 0' and 'Id'
del baby_names['Id']

# %%
baby_names.columns
del baby_names['Unnamed: 0']

# %%
baby_names.columns
# Out:
# Index(['Name', 'Year', 'Gender', 'State', 'Count'], dtype='str')

# %%
# What year has the highest number of baby names in the dataset?
baby_names.head()
# Out:
#       Name  Year Gender State  Count
# 0     Emma  2004      F    AK     62
# 1  Madison  2004      F    AK     48
# 2   Hannah  2004      F    AK     46
# 3    Grace  2004      F    AK     44
# 4    Emily  2004      F    AK     41

# %%
baby_names.groupby('Year')['Name'].nunique().idxmax()
# Out:
# np.int64(2007)

# %%
#  Are there more male or female names in the dataset?
baby_names.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1016395 entries, 0 to 1016394
# Data columns (total 5 columns):
#  #   Column  Non-Null Count    Dtype
# ---  ------  --------------    -----
#  0   Name    1016395 non-null  str
#  1   Year    1016395 non-null  int64
#  2   Gender  1016395 non-null  str
#  3   State   1016395 non-null  str
#  4   Count   1016395 non-null  int64
# dtypes: int64(2), str(3)
# memory usage: 38.8 MB

# %%
baby_names['Gender'].value_counts()
# Out:
# Gender
# F    558846
# M    457549
# Name: count, dtype: int64

# %%
baby_names.groupby('Gender')['Name'].count()
# Out:
# Gender
# F    558846
# M    457549
# Name: Name, dtype: int64

# %%
# Group the dataset by name and assign to names
names = baby_names.groupby('Name').sum()

# %%
# How many different names exist in the dataset?
len(names)
# Out:
# 17632
