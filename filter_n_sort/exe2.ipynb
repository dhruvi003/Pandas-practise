# %%
import pandas as pd

# %%
url = 'https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv'
chipo = pd.read_csv(url, sep='\t')

# %%
# How many products cost more than $10.00?
chipo.columns
chipo.head(2)
# Out:
#    order_id  quantity                     item_name choice_description  \
# 0         1         1  Chips and Fresh Tomato Salsa                NaN
# 1         1         1                          Izze       [Clementine]
#
#   item_price
# 0     $2.39
# 1     $3.39

# %%
chipo['item_price'] = chipo['item_price'].apply(lambda x: float(x[1:-1]))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 chipo['item_price'] = chipo['item_price'].apply(lambda x: float(x[1:-1]))
#       3 chipo['product_actual_price'] = chipo['item_price'] / chipo['quantity']
#       4 chipo.tail(5)
#
# File c:\Users\cdhwa\OneDrive\Documents\python-projects\ML\Pandas practise\venv\Lib\site-packages\pandas\core\series.py:5084, in Series.apply(self, func, args, by_row, **kwargs)
#    4960 def apply(
#    4961     self,
#    4962     func: AggFuncType,
#    (...)   4966     **kwargs,
#    4967 ) -> DataFrame | Series:
#    4968     """
#    4969     Invoke function on values of Series.
#    4970
#    (...)   5076     dtype: float64
#    5077     """
#    5078     return SeriesApply(
#    5079         self,
#    5080         func,
#    5081         by_row=by_row,
#    5082         args=args,
# ...

# %%
chipo.columns
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description', 'item_price',
#        'product_actual_price'],
#       dtype='str')

# %%
chipo[chipo['quantity'] > 1]
# Out:
#       order_id  quantity           item_name  \
# 4            2         2        Chicken Bowl
# 18           9         2         Canned Soda
# 51          23         2         Canned Soda
# 135         60         2  Chicken Salad Bowl
# 148         67         2       Steak Burrito
# ...        ...       ...                 ...
# 4491      1786         4   Canned Soft Drink
# 4499      1789         2   Canned Soft Drink
# 4560      1812         2   Canned Soft Drink
# 4561      1813         2  Chicken Salad Bowl
# 4582      1822         2       Bottled Water
#
#                                      choice_description  item_price  \
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98
# 18                                             [Sprite]        2.18
# 51                                       [Mountain Dew]        2.18
# 135   [Tomatillo Green Chili Salsa, [Sour Cream, Che...       22.50
# 148   [Tomatillo-Red Chili Salsa (Hot), [Rice, Chees...       17.98
# ...

# %%
chipo[chipo['product_actual_price'] > 10.00].drop_duplicates(['item_name','choice_description'])
# Out:
#       order_id  quantity        item_name  \
# 5            3         1     Chicken Bowl
# 7            4         1    Steak Burrito
# 13           7         1     Chicken Bowl
# 23          12         1  Chicken Burrito
# 39          19         1    Barbacoa Bowl
# ...        ...       ...              ...
# 4593      1825         1    Carnitas Bowl
# 4594      1825         1    Barbacoa Bowl
# 4607      1829         1    Steak Burrito
# 4610      1830         1    Steak Burrito
# 4611      1830         1   Veggie Burrito
#
#                                      choice_description  item_price  \
# 5     [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sou...       10.98
# 7     [Tomatillo Red Chili Salsa, [Fajita Vegetables...       11.75
# 13    [Fresh Tomato Salsa, [Fajita Vegetables, Rice,...       11.25
# 23    [[Tomatillo-Green Chili Salsa (Medium), Tomati...       10.98
# 39    [Roasted Chili Corn Salsa, [Fajita Vegetables,...       11.75
# ...

# %%
#  Sort by the name of the item
chipo.columns
chipo.sort_values(by=['item_name'])
# Out:
#       order_id  quantity          item_name  \
# 3389      1360         2  6 Pack Soft Drink
# 341        148         1  6 Pack Soft Drink
# 1849       749         1  6 Pack Soft Drink
# 1860       754         1  6 Pack Soft Drink
# 2713      1076         1  6 Pack Soft Drink
# ...        ...       ...                ...
# 2384       948         1  Veggie Soft Tacos
# 781        322         1  Veggie Soft Tacos
# 2851      1132         1  Veggie Soft Tacos
# 1699       688         1  Veggie Soft Tacos
# 1395       567         1  Veggie Soft Tacos
#
#                                      choice_description  item_price  \
# 3389                                        [Diet Coke]       12.98
# 341                                         [Diet Coke]        6.49
# 1849                                             [Coke]        6.49
# 1860                                        [Diet Coke]        6.49
# 2713                                             [Coke]        6.49
# ...

# %%
# What was the quantity of the most expensive item ordered?
chipo.columns
chipo.loc[chipo.item_price.idxmax()]['quantity']
# Out:
# np.int64(15)

# %%
chipo.loc[1:4]
# Out:
#    order_id  quantity                              item_name  \
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description  item_price  \
# 1                                       [Clementine]        3.39
# 2                                            [Apple]        3.39
# 3                                                NaN        2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...       16.98
#
#    product_actual_price
# 1                  3.39
# 2                  3.39
# 3                  2.39
# 4                  8.49

# %%
chipo.iloc[1:4]
# Out:
#    order_id  quantity                              item_name  \
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
#
#   choice_description  item_price  product_actual_price
# 1       [Clementine]        3.39                  3.39
# 2            [Apple]        3.39                  3.39
# 3                NaN        2.39                  2.39

# %%
# How many times was a Veggie Salad Bowl ordered?
chipo.loc[chipo.item_name == 'Veggie Salad Bowl']['quantity'].sum()
# Out:
# np.int64(18)

# %%
# How many times did someone order more than one Canned Soda?
chipo[ ( chipo["item_name"]=="Canned Soda" ) & ( chipo["quantity"]>1 )].shape[0]
# Out:
# 20
